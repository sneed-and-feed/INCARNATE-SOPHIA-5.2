# %% [markdown]
# # Tutorial: Getting Started with the Unified Field Simulator (UFS)
#
# This notebook demonstrates the core functionality of the Quantum Sovereignty Framework, focusing on Topological Data Analysis (TDA) and Dimensional Compression.

# %%
import sys
import os
sys.path.append('..')

import numpy as np
import matplotlib.pyplot as plt
from tools import funsearch_abundance

# %% [markdown]
# ## 1. Dimensional Compression
# We utilize the `funsearch_abundance` module (Banach Protocol) to demonstrate deterministic mapping.

# %%
# Generate 2D Feature Space
data = np.random.rand(100)
target_size = 200

# Execute Mapping
virtual_data = funsearch_abundance.map_to_virtual(data, target_size)

print(f"Original Dimensionality: {len(data)}")
print(f"Virtual Dimensionality:  {len(virtual_data)}")

plt.plot(virtual_data)
plt.title("Virtual Address Expansion")
plt.show()
